# %% [markdown]
# Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
#
# i. Sum of all elements
#
# ii. Sum of all elements row-wise
#
# iii. Sum of all elements column-wise

# %%
import numpy as np

gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')

print('Sum of all elements is ', np.sum(gfg))

print('Sum of all elements row-wise is ', np.sum(gfg, axis=1))

print('Sum of all elements column-wise is ', np.sum(gfg, axis=0))
# Out:
# Sum of all elements is  45
# Sum of all elements row-wise is  [[14]
#  [16]
#  [15]]
# Sum of all elements column-wise is  [[20  9 16]]

# %% [markdown]
# Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
#
# i. Sorted array
#
# ii. Indices of sorted array
#
# iii. 4 smallest elements
#
# iv. 5 largest elements
#
#  (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
#
# i. Integer elements only
#
# ii. Float elements only

# %%
#Part a
arr1 = np.array([10, 52, 62, 16, 16, 54, 453])

print('Sorted array is ', np.sort(arr1))

print('Indices of sorted array are ', np.argsort(arr1))

print('4 smallest elements are ', np.partition(arr1, 4)[:4])

print('5 largest elements are ', np.partition(arr1, 5)[-5:])
# Out:
# Sorted array is  [ 10  16  16  52  54  62 453]
# Indices of sorted array are  [0 3 4 1 5 2 6]
# 4 smallest elements are  [16 10 16 52]
# 5 largest elements are  [ 16  54  52  62 453]

# %%
#Part b
arr2 = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

print('Integer elements are ', arr2[arr2 == arr2.astype(int)])

print('Float elements are ', arr2[arr2 != arr2.astype(int)])
# Out:
# Integer elements are  [1. 2. 3. 2.]
# Float elements are  [1.2 2.2]

# %% [markdown]
# Q.3 You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.
#
# a) Generate your unique sales dataset:
#  Take the sum of the ASCII values of the initials of your first and last
# name. Call this value X. (If your initials are A B → ASCII sum = 65
# + 66 = 131 → sales = [131, 181, 231, 281, 331].)
#  Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].
#
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
#  Use broadcasting to apply this tax rate to each sales value.
#
# c) Adjust sales based on discount:
#  If sales < X+100, apply a 5% discount.
#  If sales >= X+100, apply a 10% discount.
#
# d) Expand sales data for multiple weeks:
#  Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
#  Increase sales by 2% per week using element-wise broadcasting.

# %%
X = ord('A') + ord('B')

sales = np.array([X, X+50, X+100, X+150, X+200])

print("Sales dataset:", sales)

tax_rate = ((X % 5) + 5) / 100

sales_with_tax = sales * (1 + tax_rate)

print("Sales with tax applied:", sales_with_tax)

discounted_sales = np.where(sales < X + 100, sales * 0.95, sales * 0.90)

print("Sales after discount:", discounted_sales)

sales_matrix = np.tile(sales, (3, 1))

sales_matrix = sales_matrix * (1 + 0.02) ** np.arange(3).reshape(-1, 1)

print("Sales matrix for multiple weeks with 2% weekly increase:\n", sales_matrix)
# Out:
# Sales dataset: [131 181 231 281 331]
# Sales with tax applied: [138.86 191.86 244.86 297.86 350.86]
# Sales after discount: [124.45 171.95 207.9  252.9  297.9 ]
# Sales matrix for multiple weeks with 2% weekly increase:
#  [[131.     181.     231.     281.     331.    ]
#  [133.62   184.62   235.62   286.62   337.62  ]
#  [136.2924 188.3124 240.3324 292.3524 344.3724]]

# %% [markdown]
# Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
# each function from the list below and compute y values using NumPy:
#
#  Y = x2
#
#  Y = sin(x)
#
#  Y = ex
#
#  Y = log(|x| + 1)
#
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y1 = x**2
y2 = np.sin(x)
y3 = np.exp(x)
y4 = np.log(np.abs(x) + 1)

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot x^2
axs[0, 0].plot(x, y1, label='Y = x^2')
axs[0, 0].set_title('Y = x^2')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('Y')
axs[0, 0].grid(True)

# Plot sin(x)
axs[0, 1].plot(x, y2, label='Y = sin(x)', color='r')
axs[0, 1].set_title('Y = sin(x)')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('Y')
axs[0, 1].grid(True)

# Plot exp(x)
axs[1, 0].plot(x, y3, label='Y = exp(x)', color='g')
axs[1, 0].set_title('Y = exp(x)')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('Y')
axs[1, 0].grid(True)

# Plot log(|x| + 1)
axs[1, 1].plot(x, y4, label='Y = log(|x| + 1)', color='b')
axs[1, 1].set_title('Y = log(|x| + 1)')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('Y')
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()
